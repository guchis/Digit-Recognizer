# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from keras import layers
from keras.layers import Input, Dropout, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
import keras.backend as K
from IPython.display import display, HTML
from keras.datasets import mnist
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %matplotlib inline

# %% [markdown]
# # MNIST Data Preparation

# %%
(train_set, labels_orig), (test_set, labels_test) = mnist.load_data()

# %% [markdown]
# The following function creates one hot matrix as a matrix of binary values, with rows correspond to the class number and columns correspond to training examples.

# %%
"""
#labels: A vector containing the labels
#depth: number of classes
"""

def OneHot(labels, depth):

    depth = tf.constant(depth, name = "C")
    OneHotMatrix = tf.one_hot(labels,depth,axis=0)
    sess = tf.Session()
    OneHot = sess.run(OneHotMatrix)
    sess.close()
    
    return OneHot

# %% [markdown]
# Preparing the train, cross validation, and test sets.
#
# We assign 20% of the training data samples to the cross validation set.

# %%
features_train = train_set[0:48000,:,:]
features_cross = train_set[48000:,:,:]
features_train = features_train.reshape(48000,28,28,1)
features_cross = features_cross.reshape(12000,28,28,1)
features_train = features_train/255.
features_cross = features_cross/255.

labels_train = labels_orig[0:48000,]
labels_cross = labels_orig[48000:,]
depth = 10
labels_train = OneHot(labels_train, depth).T
labels_cross = OneHot(labels_cross, depth).T

features_test = test_set.reshape(10000,28,28,1)
features_test = features_test/255.

print ("number of training examples = " + str(features_train.shape[0]))
print ("number of cross validation examples = " + str(features_cross.shape[0]))
print ("number of test examples = " + str(features_test.shape[0]))
print ("features_train shape: " + str(features_train.shape))
print ("features_cross shape: " + str(features_cross.shape))
print ("lables_train shape: " + str(labels_train.shape))
print ("lables_cross shape: " + str(labels_cross.shape))
print ("features_test shape: " + str(features_test.shape))
# Out:
# number of training examples = 48000
# number of cross validation examples = 12000
# number of test examples = 10000
# features_train shape: (48000, 28, 28, 1)
# features_cross shape: (12000, 28, 28, 1)
# lables_train shape: (48000, 10)
# lables_cross shape: (12000, 10)
# features_test shape: (10000, 28, 28, 1)

# %% [markdown]
# # Creating the CNN with Residual blocks

# %% [markdown]
# The function below implements one residual block as the identity block.

# %%
"""
#X: activation of the previous layer
#f: (f,f) will be the shape of the filter for the middle layer, you can choose it while constructing model
#filters: A list of integers defining the number of filters in the main layer, you can choose it while constructing model
#identifier1 and identifier2: will be used to name the layers
#Returns X as output activation of the residual block
"""

def ResidualBlock_Identity(X, f, filters, identifier1, identifier2):

    ConvName = 'ResBlock' + str(identifier1) + identifier2 + '_level'
    BatchNormName = 'BatchNorm' + str(identifier1) + identifier2 + '_level'
    
    F1, F2, F3 = filters
     
    initial_X = X
    
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = ConvName + '2a', kernel_initializer = glorot_uniform(seed=None))(X)
    X = BatchNormalization(axis = 3, name = BatchNormName + '2a')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = ConvName + '2b', kernel_initializer = glorot_uniform(seed=None))(X)
    X = BatchNormalization(axis = 3, name = BatchNormName + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = ConvName + '2c', kernel_initializer = glorot_uniform(seed=None))(X)
    X = BatchNormalization(axis = 3, name = BatchNormName + '2c')(X)

    X = layers.Add()([X, initial_X])
    X = Activation('relu')(X)

    return X

# %% [markdown]
# The function below implements one residual block as the convolutional block.

# %%
"""
#X: activation of the previous layer
#f: (f,f) will be the shape of the filter for the middle layer, you can choose it while constructing model
#filters: A list of integers defining the number of filters in the main layer, you can choose it while constructing model
#identifier1 and identifier2: will be used to name the layers
#s: the number of strides used in the first layer
#Returns X as output activation of the residual block
"""

def ResidualBlock_Convolutional(X, f, filters, identifier1, identifier2, s = 2):
    
    ConvName = 'ResBlock' + str(identifier1) + identifier2 + '_level'
    BatchNormName = 'BatchNorm' + str(identifier1) + identifier2 + '_level'
    
    F1, F2, F3 = filters
    
    initial_X = X

    X = Conv2D(F1, (1, 1), strides = (s,s), padding = 'valid', name = ConvName + '2a', kernel_initializer = glorot_uniform(seed=None))(X)
    X = BatchNormalization(axis = 3, name = BatchNormName + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(F2, (f, f), strides = (1,1), padding = 'same', name = ConvName + '2b', kernel_initializer = glorot_uniform(seed=None))(X)
    X = BatchNormalization(axis = 3, name = BatchNormName + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(F3, (1, 1), strides = (1,1), padding = 'valid', name = ConvName + '2c', kernel_initializer = glorot_uniform(seed=None))(X)
    X = BatchNormalization(axis = 3, name = BatchNormName + '2c')(X)

    initial_X = Conv2D(F3, (1, 1), strides = (s,s), padding = 'valid', name = ConvName + '1', kernel_initializer = glorot_uniform(seed=None))(initial_X)
    initial_X = BatchNormalization(axis = 3, name = BatchNormName + '1')(initial_X)

    X = layers.Add()([X, initial_X])
    X = Activation('relu')(X)
    
    return X

# %% [markdown]
# The function below implements a CNN with residual blocks and uses a dropout regularizer.
#
# It returns a Model() instance.

# %%
def CNNwithResidualBlocks(input_shape = (28, 28, 1), depth = 10):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)
    
    X = Conv2D(64, (5, 5), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=None))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = ResidualBlock_Convolutional(X, f = 3, filters = [32, 32, 128], identifier1 = 2, identifier2='a', s = 1)
    X = ResidualBlock_Identity(X, 3, [32, 32, 128], identifier1=2, identifier2='b')
    
    X = ResidualBlock_Convolutional(X, f = 3, filters = [64,64,256], identifier1=3, identifier2='a', s = 2)
    X = ResidualBlock_Identity(X, 3, [64,64,256], identifier1=3, identifier2='b')

    X = ResidualBlock_Convolutional(X, f = 3, filters = [128, 128, 512], identifier1=4, identifier2='a', s = 1)
    X = ResidualBlock_Identity(X, 3, [128, 128, 512], identifier1=4, identifier2='b')
    
    X = ResidualBlock_Convolutional(X, f = 3, filters = [512, 512, 2048], identifier1=5, identifier2='a', s = 2)
    X = ResidualBlock_Identity(X, 3, [512, 512, 2048], identifier1=5, identifier2='b')

    X = AveragePooling2D(pool_size=(2, 2), name="avg_pool")(X)
    
    X = Flatten()(X)
    X = Dropout(0.5)(X)
    X = Dense(depth, activation='softmax', name='fullyconnected' + str(depth), kernel_initializer = glorot_uniform(seed=None))(X)
    
    model = Model(inputs = X_input, outputs = X, name='CNNwithResidualBlocks')

    return model

# %% [markdown]
# The following command creates the model w.r.t the shape of our training data points and class numbers.

# %%
model = CNNwithResidualBlocks(input_shape = (28, 28, 1), depth = 10)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Training and Evaluation

# %% [markdown]
# Train the model on the training data set. You can choose the number of epochs or batch_size.

# %%
model.fit(features_train, labels_train, epochs = 1, batch_size = 256)
# Out:
# Train on 48000 samples
# 48000/48000 [==============================] - 2212s 46ms/sample - loss: 0.3009 - acc: 0.9139

# %% [markdown]
# Using cross validation set, you can tune the hyperparameters to improve the performance of the algorithm.

# %%
predictions = model.evaluate(features_cross, labels_cross)
print ("Loss = " + str(predictions[0]))
print ("Test Accuracy = " + str(predictions[1]))
# Out:
# /Users/saeed/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# Loss = 3.4136845741271973
# Test Accuracy = 0.106

# %% [markdown]
# The following computes the probability that each test image belongs to one of the 10 classes

# %%
Scores = model.predict(features_test)
# Out:
# /Users/saeed/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %% [markdown]
# Save the trained model, weights, etc.

# %%
model.save('DigitRecognizer.h5')

# %% [markdown]
# You can load the saved model later.

# %%
#model = load_model('DigitRecognizer.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-b68447f8f08e> in <module>()
#       2 #model.save('DigitRecognizer.h5')
#       3 #you can load the saved model later
# ----> 4 model = load_model('DigitRecognizer.h5')
#
# /opt/conda/lib/python3.6/site-packages/Keras-2.1.3-py3.6.egg/keras/models.py in load_model(filepath, custom_objects, compile)
#     235             return custom_objects[obj]
#     236         return obj
# --> 237     with h5py.File(filepath, mode='r') as f:
#     238         # instantiate model
#     239         model_config = f.attrs.get('model_config')
#
# /opt/conda/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     267             with phil:
#     268                 fapl = make_fapl(driver, libver, **kwds)
# --> 269                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     270
#     271                 if swmr_support:
#
# /opt/conda/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#      97         if swmr and swmr_support:
#      98             flags |= h5f.ACC_SWMR_READ
# ---> 99         fid = h5f.open(name, flags, fapl=fapl)
#     100     elif mode == 'r+':
#     101         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'DigitRecognizer.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# The following command returns a summary of entire model with details about number of parameters in each layer, shape of activations in each layer, etc.

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 34, 34, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 15, 15, 64)   1664        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 15, 15, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 15, 15, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 64)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# ResBlock2a_level2a (Conv2D)     (None, 7, 7, 32)     2080        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# BatchNorm2a_level2a (BatchNorma (None, 7, 7, 32)     128         ResBlock2a_level2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 7, 7, 32)     0           BatchNorm2a_level2a[0][0]
# __________________________________________________________________________________________________
# ResBlock2a_level2b (Conv2D)     (None, 7, 7, 32)     9248        activation_2[0][0]
# __________________________________________________________________________________________________
# BatchNorm2a_level2b (BatchNorma (None, 7, 7, 32)     128         ResBlock2a_level2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 7, 7, 32)     0           BatchNorm2a_level2b[0][0]
# __________________________________________________________________________________________________
# ResBlock2a_level2c (Conv2D)     (None, 7, 7, 128)    4224        activation_3[0][0]
# __________________________________________________________________________________________________
# ResBlock2a_level1 (Conv2D)      (None, 7, 7, 128)    8320        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# BatchNorm2a_level2c (BatchNorma (None, 7, 7, 128)    512         ResBlock2a_level2c[0][0]
# __________________________________________________________________________________________________
# BatchNorm2a_level1 (BatchNormal (None, 7, 7, 128)    512         ResBlock2a_level1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 7, 7, 128)    0           BatchNorm2a_level2c[0][0]
#                                                                  BatchNorm2a_level1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 7, 7, 128)    0           add_1[0][0]
# __________________________________________________________________________________________________
# ResBlock2b_level2a (Conv2D)     (None, 7, 7, 32)     4128        activation_4[0][0]
# __________________________________________________________________________________________________
# BatchNorm2b_level2a (BatchNorma (None, 7, 7, 32)     128         ResBlock2b_level2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 7, 7, 32)     0           BatchNorm2b_level2a[0][0]
# __________________________________________________________________________________________________
# ResBlock2b_level2b (Conv2D)     (None, 7, 7, 32)     9248        activation_5[0][0]
# __________________________________________________________________________________________________
# BatchNorm2b_level2b (BatchNorma (None, 7, 7, 32)     128         ResBlock2b_level2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 32)     0           BatchNorm2b_level2b[0][0]
# __________________________________________________________________________________________________
# ResBlock2b_level2c (Conv2D)     (None, 7, 7, 128)    4224        activation_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm2b_level2c (BatchNorma (None, 7, 7, 128)    512         ResBlock2b_level2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 7, 7, 128)    0           BatchNorm2b_level2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 128)    0           add_2[0][0]
# __________________________________________________________________________________________________
# ResBlock3a_level2a (Conv2D)     (None, 4, 4, 64)     8256        activation_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm3a_level2a (BatchNorma (None, 4, 4, 64)     256         ResBlock3a_level2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 4, 4, 64)     0           BatchNorm3a_level2a[0][0]
# __________________________________________________________________________________________________
# ResBlock3a_level2b (Conv2D)     (None, 4, 4, 64)     36928       activation_8[0][0]
# __________________________________________________________________________________________________
# BatchNorm3a_level2b (BatchNorma (None, 4, 4, 64)     256         ResBlock3a_level2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 4, 4, 64)     0           BatchNorm3a_level2b[0][0]
# __________________________________________________________________________________________________
# ResBlock3a_level2c (Conv2D)     (None, 4, 4, 256)    16640       activation_9[0][0]
# __________________________________________________________________________________________________
# ResBlock3a_level1 (Conv2D)      (None, 4, 4, 256)    33024       activation_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm3a_level2c (BatchNorma (None, 4, 4, 256)    1024        ResBlock3a_level2c[0][0]
# __________________________________________________________________________________________________
# BatchNorm3a_level1 (BatchNormal (None, 4, 4, 256)    1024        ResBlock3a_level1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 4, 256)    0           BatchNorm3a_level2c[0][0]
#                                                                  BatchNorm3a_level1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 4, 4, 256)    0           add_3[0][0]
# __________________________________________________________________________________________________
# ResBlock3b_level2a (Conv2D)     (None, 4, 4, 64)     16448       activation_10[0][0]
# __________________________________________________________________________________________________
# BatchNorm3b_level2a (BatchNorma (None, 4, 4, 64)     256         ResBlock3b_level2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 64)     0           BatchNorm3b_level2a[0][0]
# __________________________________________________________________________________________________
# ResBlock3b_level2b (Conv2D)     (None, 4, 4, 64)     36928       activation_11[0][0]
# __________________________________________________________________________________________________
# BatchNorm3b_level2b (BatchNorma (None, 4, 4, 64)     256         ResBlock3b_level2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 64)     0           BatchNorm3b_level2b[0][0]
# __________________________________________________________________________________________________
# ResBlock3b_level2c (Conv2D)     (None, 4, 4, 256)    16640       activation_12[0][0]
# __________________________________________________________________________________________________
# BatchNorm3b_level2c (BatchNorma (None, 4, 4, 256)    1024        ResBlock3b_level2c[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 256)    0           BatchNorm3b_level2c[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# ResBlock4a_level2a (Conv2D)     (None, 4, 4, 128)    32896       activation_13[0][0]
# __________________________________________________________________________________________________
# BatchNorm4a_level2a (BatchNorma (None, 4, 4, 128)    512         ResBlock4a_level2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 128)    0           BatchNorm4a_level2a[0][0]
# __________________________________________________________________________________________________
# ResBlock4a_level2b (Conv2D)     (None, 4, 4, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# BatchNorm4a_level2b (BatchNorma (None, 4, 4, 128)    512         ResBlock4a_level2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 128)    0           BatchNorm4a_level2b[0][0]
# __________________________________________________________________________________________________
# ResBlock4a_level2c (Conv2D)     (None, 4, 4, 512)    66048       activation_15[0][0]
# __________________________________________________________________________________________________
# ResBlock4a_level1 (Conv2D)      (None, 4, 4, 512)    131584      activation_13[0][0]
# __________________________________________________________________________________________________
# BatchNorm4a_level2c (BatchNorma (None, 4, 4, 512)    2048        ResBlock4a_level2c[0][0]
# __________________________________________________________________________________________________
# BatchNorm4a_level1 (BatchNormal (None, 4, 4, 512)    2048        ResBlock4a_level1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 512)    0           BatchNorm4a_level2c[0][0]
#                                                                  BatchNorm4a_level1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# ResBlock4b_level2a (Conv2D)     (None, 4, 4, 128)    65664       activation_16[0][0]
# __________________________________________________________________________________________________
# BatchNorm4b_level2a (BatchNorma (None, 4, 4, 128)    512         ResBlock4b_level2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 128)    0           BatchNorm4b_level2a[0][0]
# __________________________________________________________________________________________________
# ResBlock4b_level2b (Conv2D)     (None, 4, 4, 128)    147584      activation_17[0][0]
# __________________________________________________________________________________________________
# BatchNorm4b_level2b (BatchNorma (None, 4, 4, 128)    512         ResBlock4b_level2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 128)    0           BatchNorm4b_level2b[0][0]
# __________________________________________________________________________________________________
# ResBlock4b_level2c (Conv2D)     (None, 4, 4, 512)    66048       activation_18[0][0]
# __________________________________________________________________________________________________
# BatchNorm4b_level2c (BatchNorma (None, 4, 4, 512)    2048        ResBlock4b_level2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           BatchNorm4b_level2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# ResBlock5a_level2a (Conv2D)     (None, 2, 2, 512)    262656      activation_19[0][0]
# __________________________________________________________________________________________________
# BatchNorm5a_level2a (BatchNorma (None, 2, 2, 512)    2048        ResBlock5a_level2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 2, 2, 512)    0           BatchNorm5a_level2a[0][0]
# __________________________________________________________________________________________________
# ResBlock5a_level2b (Conv2D)     (None, 2, 2, 512)    2359808     activation_20[0][0]
# __________________________________________________________________________________________________
# BatchNorm5a_level2b (BatchNorma (None, 2, 2, 512)    2048        ResBlock5a_level2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 2, 2, 512)    0           BatchNorm5a_level2b[0][0]
# __________________________________________________________________________________________________
# ResBlock5a_level2c (Conv2D)     (None, 2, 2, 2048)   1050624     activation_21[0][0]
# __________________________________________________________________________________________________
# ResBlock5a_level1 (Conv2D)      (None, 2, 2, 2048)   1050624     activation_19[0][0]
# __________________________________________________________________________________________________
# BatchNorm5a_level2c (BatchNorma (None, 2, 2, 2048)   8192        ResBlock5a_level2c[0][0]
# __________________________________________________________________________________________________
# BatchNorm5a_level1 (BatchNormal (None, 2, 2, 2048)   8192        ResBlock5a_level1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 2048)   0           BatchNorm5a_level2c[0][0]
#                                                                  BatchNorm5a_level1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 2, 2, 2048)   0           add_7[0][0]
# __________________________________________________________________________________________________
# ResBlock5b_level2a (Conv2D)     (None, 2, 2, 512)    1049088     activation_22[0][0]
# __________________________________________________________________________________________________
# BatchNorm5b_level2a (BatchNorma (None, 2, 2, 512)    2048        ResBlock5b_level2a[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 2, 2, 512)    0           BatchNorm5b_level2a[0][0]
# __________________________________________________________________________________________________
# ResBlock5b_level2b (Conv2D)     (None, 2, 2, 512)    2359808     activation_23[0][0]
# __________________________________________________________________________________________________
# BatchNorm5b_level2b (BatchNorma (None, 2, 2, 512)    2048        ResBlock5b_level2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 2, 2, 512)    0           BatchNorm5b_level2b[0][0]
# __________________________________________________________________________________________________
# ResBlock5b_level2c (Conv2D)     (None, 2, 2, 2048)   1050624     activation_24[0][0]
# __________________________________________________________________________________________________
# BatchNorm5b_level2c (BatchNorma (None, 2, 2, 2048)   8192        ResBlock5b_level2c[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2, 2, 2048)   0           BatchNorm5b_level2c[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 2, 2, 2048)   0           add_8[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_25[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# fullyconnected10 (Dense)        (None, 10)           20490       dropout_1[0][0]
# ==================================================================================================
# Total params: 10,116,490
# Trainable params: 10,092,810
# Non-trainable params: 23,680
# __________________________________________________________________________________________________

# %% [markdown]
# Let's compare the actual number with corresponding prediction.
#
# Choose an index for corresponding test image to compare the predicted digit with the actual hand-written digit in the corresponding image.

# %%
index = 449
a = model.predict(features_test[index:(index + 1),:])
predicted = np.argmax(a, 1)
print("predicted_test_image = " + str(predicted)) 
print("class prediction vector [p(0), p(1), p(2), p(3), p(4), p(5)] = ")
print(a)
test_image = features_test[index,:]
test_image = test_image.reshape(28,28)
plt.imshow(test_image, cmap='gray')
# Out:
# predicted_test_image = [1]
# class prediction vector [p(0), p(1), p(2), p(3), p(4), p(5)] =
# [[0.02023107 0.71356404 0.03360732 0.00337039 0.03229734 0.07628611
#   0.00481252 0.07752556 0.01404753 0.0242582 ]]

# %% [markdown]
# The followig returns a data frame showing each ImageID in test data set and its corresponding predicted label.

# %%
PredictedLabels = np.argmax(Scores, 1)
PredictedLabels = pd.DataFrame(PredictedLabels, columns = ['Label'])
PredictedLabels.index += 1
PredictedLabels['ImageID'] = PredictedLabels.index
columnsTitles = ["ImageID","Label"]
Results = PredictedLabels.reindex(columns = columnsTitles)
print("Results :")
#Results.index.name="ImageID"
display(HTML(Results.to_html(index=False)))
# Out:
# Results :
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>ImageID</th>
#       <th>Label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>126</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>127</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>128</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>129</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>131</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>132</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>133</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>134</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>136</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>137</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>138</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>139</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>141</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>142</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>143</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>144</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <td>145</td>

# %% [markdown]
# Converts the results to a csv file.

# %%
Results.to_csv('submission.csv', index = False)
